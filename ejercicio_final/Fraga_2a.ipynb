# %% [markdown]
# ## <u>EJERCICIO 2</u>
# ### **CLASIFICACION CON Redes Convolucionales**
#
# ### PASO 0 - Importo las librerias y carga del dataset
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_lfw_people.html

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import tensorflow as tf

from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.metrics import MSE
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical

# %%
# Utilizaremos solo imagenes de 7 personas con mas de 70 imagenes disponibles.
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=1, color=False, download_if_missing=True)

# Inspeccion de los tamaños
n_samples, h, w = lfw_people.images.shape

# Datos sin divir en subconjuntos
X = lfw_people.images

# Etiquetas y clases
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = target_names.shape[0]

print("Total dataset size:")
print("h, w: (%d, %d)" % (h, w))
print("n_samples: %d" % n_samples)
print("n_classes: %d" % n_classes)
# Out:
# Total dataset size:
# h, w: (125, 94)
# n_samples: 1288
# n_classes: 7

# %%
print(target_names)
print(X.shape)
print(y.shape)
print(y[0])
print(X[0])
# Out:
# ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']
# (1288, 125, 94)
# (1288,)
# 5
# [[0.99607843 0.99607843 0.9986928  ... 0.21699347 0.20261438 0.20653595]
#  [0.99607843 0.9973857  0.99607843 ... 0.22222222 0.20261438 0.20653595]
#  [0.9986928  0.9973857  0.99346405 ... 0.2248366  0.20522876 0.20522876]
#  ...
#  [0.3150327  0.29542485 0.2535948  ... 0.39346406 0.37908497 0.37124184]
#  [0.29934642 0.2875817  0.2535948  ... 0.38562092 0.38300657 0.38300657]
#  [0.27973858 0.27320263 0.25751635 ... 0.38431373 0.38039216 0.38039216]]

# %%
#Funciones para graficar
def plot_gallery(images, number, titles, h, w, n_row=3, n_col=4):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=0.01, right=0.99, top=0.90, hspace=0.35)
    for i in range(number):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i], cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

def title(y, target_names):
    return "%s" % (target_names[y])

# %%
titles = [title(y[i], target_names) for i in range(20)]
plot_gallery(X, 12 , titles, h, w)

# %%
print(np.max(X))
print(np.min(X))
# Out:
# 1.0
# 0.0

# %% [markdown]
# ### PASO 1 - Divido las data en entrenamiento y test

# %%
# Division de los datos normalizados

porc_test = 0.25
seed = 8 #8

x_entrenar, x_test, y_entrenar, y_test = train_test_split(X, y, test_size=porc_test, random_state=seed, shuffle=True)
x_testeo = x_test.copy()
print(f"Entrenamiento: {x_entrenar.shape}")
print(f"Testeo: {x_test.shape}")
# Out:
# Entrenamiento: (966, 125, 94)
# Testeo: (322, 125, 94)

# %% [markdown]
# ### PASO 2 - Parametros para entrenamiento y  preparacion de los datos

# %%
# Estipulo los parametros para el entrenamiento de la red
lr = 0.1
epochs = 200
batch_size = 128
np.random.seed(9)

# Preparacion de la data - Salida transformada a one-hot
y_entrenar = to_categorical(y_entrenar, n_classes)
y_test = to_categorical(y_test, n_classes)

# %%
print(x_entrenar.shape)
print(x_test.shape)
# Out:
# (966, 125, 94)
# (322, 125, 94)

# %% [markdown]
# ### PASO 3 - Creacion del modelo

# %%
# Estructura de la red
input_layer = Input(shape=x_entrenar.shape[1:])
conv_1 = Conv1D(32, (3), activation="relu") (input_layer)
conv_2 = Conv1D(64, (3), activation="relu") (conv_1)
conv_3 = Conv1D(128, (3), activation="relu") (conv_2)
pool_1 = MaxPooling1D(pool_size=(2)) (conv_3)
dropout_1 = Dropout(0.3) (pool_1)
flatten_1 = Flatten() (dropout_1)
dense_1 = Dense(150, activation="relu") (flatten_1)
dense_2 = Dense(100, activation="relu") (dense_1)
dropout_2 = Dropout(0.5) (dense_2)
output_layer = Dense(n_classes, activation="softmax") (dropout_2)

# Instancia del modelo
modelo = Model(input_layer, output_layer)

# %%
optimizador = Adadelta(learning_rate=lr, rho=0.95)
modelo.compile(optimizer=optimizador, loss="categorical_crossentropy", metrics=["acc", "mse"])
modelo.summary()
# Out:
# Model: "functional_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)     │ (None, 125, 94)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_35 (Conv1D)              │ (None, 123, 32)        │         9,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_36 (Conv1D)              │ (None, 121, 64)        │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_37 (Conv1D)              │ (None, 119, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_16 (MaxPooling1D) │ (None, 59, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 59, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 7552)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 150)            │     1,132,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 100)            │        15,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 7)              │           707 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,188,725 (4.53 MB)
#  Trainable params: 1,188,725 (4.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### PASO 4 - Entrenamiento del modelo

# %%
inicio = time.time()
historia = modelo.fit(x_entrenar, y_entrenar, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), shuffle=True, verbose=1)
final = time.time()
print('\nTiempo que demoro el entrenamiento: {:.3f} segundos'.format(final-inicio))
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - acc: 0.2993 - loss: 1.8651 - mse: 0.1184 - val_acc: 0.4441 - val_loss: 1.6486 - val_mse: 0.1064
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3852 - loss: 1.7313 - mse: 0.1118 - val_acc: 0.4441 - val_loss: 1.6311 - val_mse: 0.1053
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.3906 - loss: 1.7391 - mse: 0.1120 - val_acc: 0.4441 - val_loss: 1.6249 - val_mse: 0.1051
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3938 - loss: 1.7233 - mse: 0.1111 - val_acc: 0.4441 - val_loss: 1.6335 - val_mse: 0.1058
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.3942 - loss: 1.6986 - mse: 0.1097 - val_acc: 0.4441 - val_loss: 1.6092 - val_mse: 0.1040
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4029 - loss: 1.7056 - mse: 0.1101 - val_acc: 0.4441 - val_loss: 1.6437 - val_mse: 0.1068
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4078 - loss: 1.7153 - mse: 0.1105 - val_acc: 0.4441 - val_loss: 1.6016 - val_mse: 0.1033
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4225 - loss: 1.6830 - mse: 0.1086 - val_acc: 0.4441 - val_loss: 1.6181 - val_mse: 0.1051
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4102 - loss: 1.6655 - mse: 0.1078 - val_acc: 0.4472 - val_loss: 1.6155 - val_mse: 0.1051
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.3969 - loss: 1.6662 - mse: 0.1081 - val_acc: 0.4441 - val_loss: 1.5833 - val_mse: 0.1022
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.3993 - loss: 1.6687 - mse: 0.1072 - val_acc: 0.4441 - val_loss: 1.5443 - val_mse: 0.0993
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.3958 - loss: 1.6678 - mse: 0.1077 - val_acc: 0.4472 - val_loss: 1.5278 - val_mse: 0.0983
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.3978 - loss: 1.6380 - mse: 0.1053 - val_acc: 0.4441 - val_loss: 1.5475 - val_mse: 0.1008
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4159 - loss: 1.6330 - mse: 0.1056 - val_acc: 0.4596 - val_loss: 1.5024 - val_mse: 0.0969
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4138 - loss: 1.5876 - mse: 0.1024 - val_acc: 0.4907 - val_loss: 1.4856 - val_mse: 0.0959
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4461 - loss: 1.5596 - mse: 0.1002 - val_acc: 0.4534 - val_loss: 1.4264 - val_mse: 0.0920
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4538 - loss: 1.5141 - mse: 0.0975 - val_acc: 0.4876 - val_loss: 1.4029 - val_mse: 0.0906
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4702 - loss: 1.4917 - mse: 0.0959 - val_acc: 0.4503 - val_loss: 1.3975 - val_mse: 0.0918
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4710 - loss: 1.4785 - mse: 0.0959 - val_acc: 0.4503 - val_loss: 1.4056 - val_mse: 0.0937
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4781 - loss: 1.4501 - mse: 0.0951 - val_acc: 0.5652 - val_loss: 1.4198 - val_mse: 0.0922
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.4966 - loss: 1.4152 - mse: 0.0927 - val_acc: 0.5435 - val_loss: 1.4369 - val_mse: 0.0936
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5235 - loss: 1.4050 - mse: 0.0918 - val_acc: 0.5466 - val_loss: 1.2402 - val_mse: 0.0823
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5378 - loss: 1.3152 - mse: 0.0862 - val_acc: 0.5466 - val_loss: 1.2234 - val_mse: 0.0802
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5509 - loss: 1.3110 - mse: 0.0860 - val_acc: 0.6118 - val_loss: 1.1557 - val_mse: 0.0767
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5962 - loss: 1.1962 - mse: 0.0790 - val_acc: 0.6553 - val_loss: 1.1942 - val_mse: 0.0782
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5556 - loss: 1.2738 - mse: 0.0846 - val_acc: 0.6398 - val_loss: 1.1832 - val_mse: 0.0780
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5903 - loss: 1.2297 - mse: 0.0816 - val_acc: 0.6522 - val_loss: 1.1229 - val_mse: 0.0738
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5889 - loss: 1.1512 - mse: 0.0779 - val_acc: 0.6118 - val_loss: 1.0835 - val_mse: 0.0759
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.5816 - loss: 1.2064 - mse: 0.0811 - val_acc: 0.6770 - val_loss: 0.9469 - val_mse: 0.0645
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6660 - loss: 1.0262 - mse: 0.0686 - val_acc: 0.6553 - val_loss: 0.9528 - val_mse: 0.0660
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6651 - loss: 1.0098 - mse: 0.0686 - val_acc: 0.6894 - val_loss: 0.8795 - val_mse: 0.0602
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6613 - loss: 1.0105 - mse: 0.0678 - val_acc: 0.6646 - val_loss: 0.9576 - val_mse: 0.0675
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.6388 - loss: 1.0240 - mse: 0.0707 - val_acc: 0.6988 - val_loss: 0.9072 - val_mse: 0.0615
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6492 - loss: 0.9984 - mse: 0.0672 - val_acc: 0.7050 - val_loss: 0.8522 - val_mse: 0.0594
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6758 - loss: 0.9325 - mse: 0.0639 - val_acc: 0.7516 - val_loss: 0.7860 - val_mse: 0.0530
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7070 - loss: 0.8633 - mse: 0.0590 - val_acc: 0.7050 - val_loss: 0.8487 - val_mse: 0.0586
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7099 - loss: 0.8702 - mse: 0.0594 - val_acc: 0.7547 - val_loss: 0.7812 - val_mse: 0.0530
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.6788 - loss: 0.8799 - mse: 0.0599 - val_acc: 0.7578 - val_loss: 0.8165 - val_mse: 0.0541
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7125 - loss: 0.8731 - mse: 0.0597 - val_acc: 0.7578 - val_loss: 0.7967 - val_mse: 0.0533
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.7194 - loss: 0.8475 - mse: 0.0579 - val_acc: 0.7516 - val_loss: 0.7390 - val_mse: 0.0508
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.7005 - loss: 0.8278 - mse: 0.0583 - val_acc: 0.7143 - val_loss: 0.7870 - val_mse: 0.0544
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7122 - loss: 0.8335 - mse: 0.0565 - val_acc: 0.7702 - val_loss: 0.6784 - val_mse: 0.0464
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.7594 - loss: 0.7239 - mse: 0.0496 - val_acc: 0.7484 - val_loss: 0.7545 - val_mse: 0.0503
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.7390 - loss: 0.8081 - mse: 0.0561 - val_acc: 0.7857 - val_loss: 0.6913 - val_mse: 0.0458
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.7591 - loss: 0.6883 - mse: 0.0478 - val_acc: 0.7298 - val_loss: 0.8633 - val_mse: 0.0563
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.7108 - loss: 0.8402 - mse: 0.0576 - val_acc: 0.7981 - val_loss: 0.6418 - val_mse: 0.0432
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.7410 - loss: 0.7329 - mse: 0.0518 - val_acc: 0.7981 - val_loss: 0.6548 - val_mse: 0.0442
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.7415 - loss: 0.7695 - mse: 0.0529 - val_acc: 0.7081 - val_loss: 0.7569 - val_mse: 0.0526
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.7172 - loss: 0.7808 - mse: 0.0547 - val_acc: 0.8075 - val_loss: 0.6326 - val_mse: 0.0420
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7601 - loss: 0.7207 - mse: 0.0498 - val_acc: 0.8168 - val_loss: 0.5946 - val_mse: 0.0395
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.7759 - loss: 0.6453 - mse: 0.0452 - val_acc: 0.8043 - val_loss: 0.5956 - val_mse: 0.0397
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7689 - loss: 0.6301 - mse: 0.0436 - val_acc: 0.7764 - val_loss: 0.6252 - val_mse: 0.0435
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7541 - loss: 0.6845 - mse: 0.0479 - val_acc: 0.8043 - val_loss: 0.5926 - val_mse: 0.0398
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.7689 - loss: 0.6472 - mse: 0.0454 - val_acc: 0.7578 - val_loss: 0.7010 - val_mse: 0.0466
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7785 - loss: 0.6439 - mse: 0.0442 - val_acc: 0.8106 - val_loss: 0.5733 - val_mse: 0.0384
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7988 - loss: 0.6096 - mse: 0.0414 - val_acc: 0.8230 - val_loss: 0.5719 - val_mse: 0.0382
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.7958 - loss: 0.5998 - mse: 0.0425 - val_acc: 0.7329 - val_loss: 0.7650 - val_mse: 0.0511
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7636 - loss: 0.6906 - mse: 0.0489 - val_acc: 0.8012 - val_loss: 0.6023 - val_mse: 0.0413
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8068 - loss: 0.5539 - mse: 0.0390 - val_acc: 0.8230 - val_loss: 0.5811 - val_mse: 0.0388
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8039 - loss: 0.5764 - mse: 0.0400 - val_acc: 0.8012 - val_loss: 0.5612 - val_mse: 0.0380
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8346 - loss: 0.5133 - mse: 0.0353 - val_acc: 0.8075 - val_loss: 0.5565 - val_mse: 0.0366
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8372 - loss: 0.4836 - mse: 0.0342 - val_acc: 0.8261 - val_loss: 0.5602 - val_mse: 0.0369
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8193 - loss: 0.5239 - mse: 0.0363 - val_acc: 0.7702 - val_loss: 0.6388 - val_mse: 0.0434
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7952 - loss: 0.5460 - mse: 0.0386 - val_acc: 0.8478 - val_loss: 0.5122 - val_mse: 0.0335
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8413 - loss: 0.4682 - mse: 0.0324 - val_acc: 0.7733 - val_loss: 0.7102 - val_mse: 0.0472
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.7978 - loss: 0.6322 - mse: 0.0424 - val_acc: 0.8199 - val_loss: 0.5468 - val_mse: 0.0365
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8481 - loss: 0.4955 - mse: 0.0341 - val_acc: 0.7857 - val_loss: 0.5985 - val_mse: 0.0420
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8178 - loss: 0.5559 - mse: 0.0376 - val_acc: 0.8168 - val_loss: 0.5170 - val_mse: 0.0346
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8472 - loss: 0.4513 - mse: 0.0315 - val_acc: 0.8385 - val_loss: 0.5086 - val_mse: 0.0325
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8526 - loss: 0.4715 - mse: 0.0318 - val_acc: 0.7981 - val_loss: 0.6306 - val_mse: 0.0408
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8133 - loss: 0.5105 - mse: 0.0368 - val_acc: 0.8447 - val_loss: 0.5183 - val_mse: 0.0333
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8509 - loss: 0.4546 - mse: 0.0323 - val_acc: 0.8447 - val_loss: 0.5044 - val_mse: 0.0323
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8503 - loss: 0.4608 - mse: 0.0316 - val_acc: 0.8261 - val_loss: 0.5285 - val_mse: 0.0349
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8336 - loss: 0.4593 - mse: 0.0334 - val_acc: 0.8354 - val_loss: 0.4980 - val_mse: 0.0328
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8515 - loss: 0.4726 - mse: 0.0323 - val_acc: 0.8230 - val_loss: 0.4968 - val_mse: 0.0335
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8549 - loss: 0.4325 - mse: 0.0311 - val_acc: 0.8447 - val_loss: 0.5056 - val_mse: 0.0321
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.8510 - loss: 0.4063 - mse: 0.0289 - val_acc: 0.8292 - val_loss: 0.5540 - val_mse: 0.0360
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8476 - loss: 0.4456 - mse: 0.0320 - val_acc: 0.8075 - val_loss: 0.5551 - val_mse: 0.0367
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8338 - loss: 0.4688 - mse: 0.0333 - val_acc: 0.8540 - val_loss: 0.4781 - val_mse: 0.0308
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.8784 - loss: 0.3710 - mse: 0.0262 - val_acc: 0.8447 - val_loss: 0.4921 - val_mse: 0.0315
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.8770 - loss: 0.3882 - mse: 0.0274 - val_acc: 0.8416 - val_loss: 0.5530 - val_mse: 0.0344
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.8582 - loss: 0.3795 - mse: 0.0276 - val_acc: 0.8385 - val_loss: 0.4683 - val_mse: 0.0307
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8811 - loss: 0.3417 - mse: 0.0241 - val_acc: 0.8354 - val_loss: 0.5052 - val_mse: 0.0339
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.8623 - loss: 0.3779 - mse: 0.0277 - val_acc: 0.8261 - val_loss: 0.5146 - val_mse: 0.0344
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8757 - loss: 0.3637 - mse: 0.0258 - val_acc: 0.8168 - val_loss: 0.5007 - val_mse: 0.0341
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8746 - loss: 0.3637 - mse: 0.0263 - val_acc: 0.8043 - val_loss: 0.5304 - val_mse: 0.0368
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9008 - loss: 0.3428 - mse: 0.0235 - val_acc: 0.8478 - val_loss: 0.4885 - val_mse: 0.0317
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8890 - loss: 0.3314 - mse: 0.0239 - val_acc: 0.8385 - val_loss: 0.4917 - val_mse: 0.0317
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8779 - loss: 0.3653 - mse: 0.0263 - val_acc: 0.8075 - val_loss: 0.5403 - val_mse: 0.0368
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8608 - loss: 0.3672 - mse: 0.0270 - val_acc: 0.8447 - val_loss: 0.4738 - val_mse: 0.0302
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.8925 - loss: 0.3531 - mse: 0.0251 - val_acc: 0.8416 - val_loss: 0.4797 - val_mse: 0.0310
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8828 - loss: 0.3372 - mse: 0.0243 - val_acc: 0.8292 - val_loss: 0.5077 - val_mse: 0.0339
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8901 - loss: 0.3148 - mse: 0.0225 - val_acc: 0.8385 - val_loss: 0.5093 - val_mse: 0.0331
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.8940 - loss: 0.3144 - mse: 0.0221 - val_acc: 0.8385 - val_loss: 0.4715 - val_mse: 0.0304
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9179 - loss: 0.2739 - mse: 0.0192 - val_acc: 0.8168 - val_loss: 0.5556 - val_mse: 0.0357
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8629 - loss: 0.3966 - mse: 0.0288 - val_acc: 0.8447 - val_loss: 0.4970 - val_mse: 0.0312
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8871 - loss: 0.3491 - mse: 0.0247 - val_acc: 0.8509 - val_loss: 0.4658 - val_mse: 0.0299
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8934 - loss: 0.3108 - mse: 0.0222 - val_acc: 0.8354 - val_loss: 0.5020 - val_mse: 0.0322
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9149 - loss: 0.2733 - mse: 0.0191 - val_acc: 0.8447 - val_loss: 0.4534 - val_mse: 0.0290
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9082 - loss: 0.2785 - mse: 0.0201 - val_acc: 0.8323 - val_loss: 0.4866 - val_mse: 0.0308
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9094 - loss: 0.2617 - mse: 0.0191 - val_acc: 0.8292 - val_loss: 0.4671 - val_mse: 0.0301
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9190 - loss: 0.2634 - mse: 0.0188 - val_acc: 0.8416 - val_loss: 0.4934 - val_mse: 0.0307
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.8819 - loss: 0.3126 - mse: 0.0229 - val_acc: 0.8385 - val_loss: 0.4847 - val_mse: 0.0318
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.8953 - loss: 0.3097 - mse: 0.0218 - val_acc: 0.8354 - val_loss: 0.5322 - val_mse: 0.0355
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9054 - loss: 0.2903 - mse: 0.0202 - val_acc: 0.8478 - val_loss: 0.4627 - val_mse: 0.0302
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9315 - loss: 0.2282 - mse: 0.0158 - val_acc: 0.8416 - val_loss: 0.5047 - val_mse: 0.0319
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9095 - loss: 0.2826 - mse: 0.0199 - val_acc: 0.8385 - val_loss: 0.5011 - val_mse: 0.0311
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9276 - loss: 0.2277 - mse: 0.0156 - val_acc: 0.8478 - val_loss: 0.4668 - val_mse: 0.0294
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9199 - loss: 0.2443 - mse: 0.0176 - val_acc: 0.8540 - val_loss: 0.4795 - val_mse: 0.0312
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.8905 - loss: 0.2893 - mse: 0.0220 - val_acc: 0.8478 - val_loss: 0.4682 - val_mse: 0.0295
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9192 - loss: 0.2620 - mse: 0.0181 - val_acc: 0.8447 - val_loss: 0.4929 - val_mse: 0.0311
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9277 - loss: 0.2346 - mse: 0.0173 - val_acc: 0.8634 - val_loss: 0.4771 - val_mse: 0.0288
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9132 - loss: 0.2504 - mse: 0.0182 - val_acc: 0.8540 - val_loss: 0.4884 - val_mse: 0.0294
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9187 - loss: 0.2404 - mse: 0.0171 - val_acc: 0.8137 - val_loss: 0.6535 - val_mse: 0.0411
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9282 - loss: 0.2336 - mse: 0.0161 - val_acc: 0.8323 - val_loss: 0.5227 - val_mse: 0.0344
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9280 - loss: 0.2364 - mse: 0.0164 - val_acc: 0.8447 - val_loss: 0.4843 - val_mse: 0.0297
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9358 - loss: 0.2131 - mse: 0.0148 - val_acc: 0.8509 - val_loss: 0.4920 - val_mse: 0.0309
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9250 - loss: 0.2182 - mse: 0.0156 - val_acc: 0.8261 - val_loss: 0.5650 - val_mse: 0.0354
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9300 - loss: 0.2340 - mse: 0.0165 - val_acc: 0.8447 - val_loss: 0.5127 - val_mse: 0.0307
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9104 - loss: 0.2298 - mse: 0.0171 - val_acc: 0.8354 - val_loss: 0.5324 - val_mse: 0.0340
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9164 - loss: 0.2303 - mse: 0.0169 - val_acc: 0.8416 - val_loss: 0.5152 - val_mse: 0.0319
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9115 - loss: 0.2445 - mse: 0.0177 - val_acc: 0.8602 - val_loss: 0.4672 - val_mse: 0.0284
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9324 - loss: 0.2061 - mse: 0.0145 - val_acc: 0.8571 - val_loss: 0.5008 - val_mse: 0.0308
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9500 - loss: 0.1775 - mse: 0.0124 - val_acc: 0.8602 - val_loss: 0.4904 - val_mse: 0.0288
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9389 - loss: 0.1919 - mse: 0.0134 - val_acc: 0.8602 - val_loss: 0.4898 - val_mse: 0.0302
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9393 - loss: 0.2055 - mse: 0.0149 - val_acc: 0.8571 - val_loss: 0.5112 - val_mse: 0.0311
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9493 - loss: 0.1724 - mse: 0.0117 - val_acc: 0.8385 - val_loss: 0.5015 - val_mse: 0.0326
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9223 - loss: 0.2334 - mse: 0.0170 - val_acc: 0.8602 - val_loss: 0.4735 - val_mse: 0.0287
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9424 - loss: 0.1927 - mse: 0.0134 - val_acc: 0.8665 - val_loss: 0.4641 - val_mse: 0.0287
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9495 - loss: 0.1810 - mse: 0.0127 - val_acc: 0.8447 - val_loss: 0.5210 - val_mse: 0.0313
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9497 - loss: 0.1741 - mse: 0.0120 - val_acc: 0.8571 - val_loss: 0.4846 - val_mse: 0.0288
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9568 - loss: 0.1637 - mse: 0.0113 - val_acc: 0.8634 - val_loss: 0.4894 - val_mse: 0.0293
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9422 - loss: 0.1879 - mse: 0.0140 - val_acc: 0.8509 - val_loss: 0.4933 - val_mse: 0.0284
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9471 - loss: 0.1925 - mse: 0.0135 - val_acc: 0.8571 - val_loss: 0.4679 - val_mse: 0.0284
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9345 - loss: 0.2255 - mse: 0.0155 - val_acc: 0.8540 - val_loss: 0.5045 - val_mse: 0.0298
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9452 - loss: 0.1951 - mse: 0.0141 - val_acc: 0.8540 - val_loss: 0.5219 - val_mse: 0.0311
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9309 - loss: 0.1993 - mse: 0.0149 - val_acc: 0.8571 - val_loss: 0.4958 - val_mse: 0.0299
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9340 - loss: 0.2156 - mse: 0.0156 - val_acc: 0.8447 - val_loss: 0.5296 - val_mse: 0.0332
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9470 - loss: 0.1777 - mse: 0.0127 - val_acc: 0.8602 - val_loss: 0.4892 - val_mse: 0.0289
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9356 - loss: 0.1966 - mse: 0.0147 - val_acc: 0.8571 - val_loss: 0.5424 - val_mse: 0.0313
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9451 - loss: 0.1824 - mse: 0.0132 - val_acc: 0.8789 - val_loss: 0.4766 - val_mse: 0.0284
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9543 - loss: 0.1399 - mse: 0.0101 - val_acc: 0.8634 - val_loss: 0.5181 - val_mse: 0.0306
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9538 - loss: 0.1621 - mse: 0.0111 - val_acc: 0.8696 - val_loss: 0.4876 - val_mse: 0.0285
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9571 - loss: 0.1441 - mse: 0.0102 - val_acc: 0.8540 - val_loss: 0.5139 - val_mse: 0.0313
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9593 - loss: 0.1387 - mse: 0.0099 - val_acc: 0.8602 - val_loss: 0.4952 - val_mse: 0.0284
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9494 - loss: 0.1525 - mse: 0.0107 - val_acc: 0.8665 - val_loss: 0.5035 - val_mse: 0.0290
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9479 - loss: 0.1515 - mse: 0.0112 - val_acc: 0.8634 - val_loss: 0.5221 - val_mse: 0.0303
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.9436 - loss: 0.1698 - mse: 0.0122 - val_acc: 0.8665 - val_loss: 0.4716 - val_mse: 0.0274
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9610 - loss: 0.1412 - mse: 0.0096 - val_acc: 0.8758 - val_loss: 0.4902 - val_mse: 0.0285
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9574 - loss: 0.1570 - mse: 0.0111 - val_acc: 0.8665 - val_loss: 0.4748 - val_mse: 0.0276
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9509 - loss: 0.1425 - mse: 0.0101 - val_acc: 0.8571 - val_loss: 0.4847 - val_mse: 0.0287
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9551 - loss: 0.1433 - mse: 0.0102 - val_acc: 0.8571 - val_loss: 0.5060 - val_mse: 0.0289
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9523 - loss: 0.1426 - mse: 0.0099 - val_acc: 0.8354 - val_loss: 0.5792 - val_mse: 0.0348
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9244 - loss: 0.1801 - mse: 0.0138 - val_acc: 0.8665 - val_loss: 0.5066 - val_mse: 0.0298
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9603 - loss: 0.1330 - mse: 0.0097 - val_acc: 0.8416 - val_loss: 0.5796 - val_mse: 0.0343
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9683 - loss: 0.1281 - mse: 0.0088 - val_acc: 0.8634 - val_loss: 0.5154 - val_mse: 0.0294
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9533 - loss: 0.1469 - mse: 0.0105 - val_acc: 0.8789 - val_loss: 0.4896 - val_mse: 0.0286
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9434 - loss: 0.1570 - mse: 0.0121 - val_acc: 0.8602 - val_loss: 0.5201 - val_mse: 0.0295
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.9583 - loss: 0.1232 - mse: 0.0088 - val_acc: 0.8634 - val_loss: 0.5117 - val_mse: 0.0290
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9331 - loss: 0.1720 - mse: 0.0134 - val_acc: 0.8820 - val_loss: 0.4888 - val_mse: 0.0279
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9578 - loss: 0.1435 - mse: 0.0102 - val_acc: 0.8571 - val_loss: 0.4811 - val_mse: 0.0284
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9671 - loss: 0.1179 - mse: 0.0081 - val_acc: 0.8696 - val_loss: 0.5015 - val_mse: 0.0286
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9614 - loss: 0.1387 - mse: 0.0099 - val_acc: 0.8665 - val_loss: 0.5174 - val_mse: 0.0299
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9649 - loss: 0.1194 - mse: 0.0082 - val_acc: 0.8571 - val_loss: 0.5856 - val_mse: 0.0332
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9668 - loss: 0.1154 - mse: 0.0077 - val_acc: 0.8602 - val_loss: 0.5218 - val_mse: 0.0301
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9586 - loss: 0.1403 - mse: 0.0102 - val_acc: 0.8727 - val_loss: 0.5195 - val_mse: 0.0289
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9614 - loss: 0.1259 - mse: 0.0092 - val_acc: 0.8602 - val_loss: 0.5268 - val_mse: 0.0298
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9495 - loss: 0.1333 - mse: 0.0098 - val_acc: 0.8727 - val_loss: 0.5399 - val_mse: 0.0298
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9786 - loss: 0.0958 - mse: 0.0061 - val_acc: 0.8758 - val_loss: 0.4832 - val_mse: 0.0276
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9612 - loss: 0.1177 - mse: 0.0082 - val_acc: 0.8634 - val_loss: 0.5591 - val_mse: 0.0313
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9709 - loss: 0.0999 - mse: 0.0067 - val_acc: 0.8727 - val_loss: 0.4988 - val_mse: 0.0276
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9675 - loss: 0.1278 - mse: 0.0088 - val_acc: 0.8634 - val_loss: 0.5159 - val_mse: 0.0291
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9667 - loss: 0.1192 - mse: 0.0085 - val_acc: 0.8758 - val_loss: 0.5228 - val_mse: 0.0288
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9713 - loss: 0.1183 - mse: 0.0081 - val_acc: 0.8602 - val_loss: 0.5134 - val_mse: 0.0301
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9783 - loss: 0.0924 - mse: 0.0059 - val_acc: 0.8758 - val_loss: 0.5151 - val_mse: 0.0291
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9712 - loss: 0.1006 - mse: 0.0071 - val_acc: 0.8478 - val_loss: 0.5404 - val_mse: 0.0311
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9701 - loss: 0.1195 - mse: 0.0085 - val_acc: 0.8789 - val_loss: 0.4975 - val_mse: 0.0279
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9698 - loss: 0.0977 - mse: 0.0068 - val_acc: 0.8634 - val_loss: 0.5310 - val_mse: 0.0299
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9708 - loss: 0.1181 - mse: 0.0084 - val_acc: 0.8665 - val_loss: 0.5088 - val_mse: 0.0288
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9720 - loss: 0.0998 - mse: 0.0068 - val_acc: 0.8758 - val_loss: 0.5002 - val_mse: 0.0279
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9581 - loss: 0.1179 - mse: 0.0083 - val_acc: 0.8634 - val_loss: 0.5181 - val_mse: 0.0301
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9754 - loss: 0.0950 - mse: 0.0062 - val_acc: 0.8727 - val_loss: 0.5197 - val_mse: 0.0282
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9837 - loss: 0.0806 - mse: 0.0052 - val_acc: 0.8634 - val_loss: 0.5299 - val_mse: 0.0315
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9671 - loss: 0.1051 - mse: 0.0076 - val_acc: 0.8540 - val_loss: 0.5161 - val_mse: 0.0305
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9746 - loss: 0.0849 - mse: 0.0060 - val_acc: 0.8696 - val_loss: 0.5169 - val_mse: 0.0287
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9720 - loss: 0.1152 - mse: 0.0076 - val_acc: 0.8696 - val_loss: 0.5086 - val_mse: 0.0284
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9724 - loss: 0.0912 - mse: 0.0066 - val_acc: 0.8665 - val_loss: 0.5324 - val_mse: 0.0305
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9775 - loss: 0.0852 - mse: 0.0058 - val_acc: 0.8571 - val_loss: 0.5408 - val_mse: 0.0302
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9742 - loss: 0.0891 - mse: 0.0059 - val_acc: 0.8665 - val_loss: 0.5434 - val_mse: 0.0291
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9709 - loss: 0.0961 - mse: 0.0069 - val_acc: 0.8540 - val_loss: 0.5203 - val_mse: 0.0293
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9687 - loss: 0.0989 - mse: 0.0073 - val_acc: 0.8416 - val_loss: 0.5721 - val_mse: 0.0338
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9707 - loss: 0.0900 - mse: 0.0062 - val_acc: 0.8634 - val_loss: 0.5162 - val_mse: 0.0285
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9807 - loss: 0.0740 - mse: 0.0049 - val_acc: 0.8602 - val_loss: 0.5729 - val_mse: 0.0312
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9692 - loss: 0.0988 - mse: 0.0071 - val_acc: 0.8758 - val_loss: 0.5132 - val_mse: 0.0277
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9660 - loss: 0.1018 - mse: 0.0076 - val_acc: 0.8447 - val_loss: 0.5587 - val_mse: 0.0330
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9704 - loss: 0.0926 - mse: 0.0064 - val_acc: 0.8634 - val_loss: 0.5263 - val_mse: 0.0293
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9812 - loss: 0.0821 - mse: 0.0056 - val_acc: 0.8509 - val_loss: 0.5187 - val_mse: 0.0300
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9738 - loss: 0.0842 - mse: 0.0056 - val_acc: 0.8758 - val_loss: 0.5207 - val_mse: 0.0274
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.9814 - loss: 0.0721 - mse: 0.0048 - val_acc: 0.8727 - val_loss: 0.5402 - val_mse: 0.0286
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9838 - loss: 0.0762 - mse: 0.0049 - val_acc: 0.8634 - val_loss: 0.5230 - val_mse: 0.0290
#
# Tiempo que demoro el entrenamiento: 51.038 segundos

# %% [markdown]
# ### PASO 5 - Evaluacion del entrenamiento del modelo

# %%
historia.history.keys()
# Out:
# dict_keys(['acc', 'loss', 'mse', 'val_acc', 'val_loss', 'val_mse'])

# %%
def grafico_comprobacion(train, test, minimo, maximo, ylabel):

    plt.plot(historia.history[train], linewidth=1, label="Entrenamiento")
    plt.plot(historia.history[test], linewidth=1, label="Testeo")
    plt.xlabel("Epochs")
    plt.ylabel(ylabel)
    plt.axis([0, epochs, minimo, maximo])
    plt.legend(loc="best")

# %%
f = plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
grafico_comprobacion("mse", "val_mse", 0, 0.15, "MSE")

plt.subplot(1,3,2)
grafico_comprobacion("acc", "val_acc", 0.3, 1, "Accuracy")	

plt.subplot(1,3,3)
grafico_comprobacion("loss", "val_loss", 0, 2, "Loss")

plt.show()

# %%
acc_test = modelo.evaluate(x_test, y_test,verbose=0)
acc_entrenamiento = modelo.evaluate(x_entrenar, y_entrenar,verbose=0)

print(f"Accuracy sobre conjunto de entrenamiento: {acc_entrenamiento[1]}")
print(f"Accuracy sobre conjunto de validacion:{acc_test[1]}")
# Out:
# Accuracy sobre conjunto de entrenamiento: 0.998964786529541
# Accuracy sobre conjunto de validacion:0.8633540272712708

# %% [markdown]
# ### PASO 6 - Predicciones y evaluacion con Matriz de Confusion

# %%
# Predicciones con la data de testeo
y_prediccion = modelo.predict(x_test, verbose=1)

# Matriz de confusion y grafica
y_test_cm = np.argmax(y_test, axis=1)
y_prediccion_cm = np.argmax(y_prediccion, axis=1)
confm = confusion_matrix(y_test_cm, y_prediccion_cm)
print(f"\nMatriz de confusion")
print(confm)

f = plt.figure(figsize=(10,10))
plt.imshow(confm, cmap="YlOrRd")
plt.xlabel("Etiquetas de prediccion")
plt.ylabel("Etiquetas de testeo")
plt.xticks(np.arange(7), target_names,rotation=90)
plt.yticks(np.arange(7), target_names,rotation=0)
for i in range(len(target_names)):
    for j in range(len(target_names)):
        text = plt.text(j, i, confm[i, j], ha="center", va="center", color="black")
plt.colorbar()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Matriz de confusion
# [[ 15   2   0   1   0   0   1]
#  [  0  43   2   8   0   1   2]
#  [  2   0  23   2   0   0   1]
#  [  4   1   4 132   2   0   0]
#  [  0   0   2   0  21   0   2]
#  [  0   1   0   1   0  14   0]
#  [  1   1   0   3   0   0  30]]

# %% [markdown]
# ### PASO 7 - Otra verificacion

# %%
num = [36, 63, 83, 101]

plt.figure(figsize=(1.8 * 4, 2.4 * 1))
plt.subplots_adjust(bottom=0, left=0.01, right=1.5, top=0.90, hspace=0.35)
for i, j in enumerate(num):
    plt.subplot(1, 4, i + 1)
    plt.imshow(x_testeo[j], cmap=plt.cm.gray)
    plt.title(f"Prediccion: {target_names[y_prediccion_cm[j]]}", size=12)
    plt.xlabel(f"Label data: {target_names[y_test_cm[j]]}")
    plt.xticks(())
    plt.yticks(())

# %% [markdown]
# ### PASO 8 - Conclusiones
# Tras experimentar con diversas configuraciones, incluyendo el número de capas, la cantidad de neuronas en cada una y diferentes hiperparámetros, logré diseñar una estructura de modelo que supera los requisitos de precisión especificados en el ejercicio.
#
# En esta arquitectura, dado que los datos de entrada están representados como un vector de dos dimensiones que pasan por tres capas convolucionales, la cantidad de parámetros entrenables es significativamente menor en comparación con el modelo utilizado en el ejercicio 1.
#
# Al analizar los gráficos de MSE, Loss y Accuracy, se observan patrones zigzagueantes. Este ruido fue reducido significativamente ajustando el valor del learning rate y el tamaño del batch. Cabe destacar que este fenómeno se presenta con mayor intensidad en comparación con el modelo de redes densas.
#
# Este modelo tiene la ventaja de requerir menos tiempo de entrenamiento y recursos computacionales más modestos, eliminando la necesidad de utilizar una GPU.
#
# Finalmente, la matriz de confusión muestra que el modelo es notablemente más eficiente que el de redes densas, evidenciándose en una menor cantidad de errores de clasificación fuera de la diagonal principal.
